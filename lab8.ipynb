# %%
import numpy as np
import scipy as sp
import pandas as pd
import pylab as plt
import sklearn.datasets as ds
import sklearn.tree as tree
import sklearn.ensemble as ensemble
import sklearn.metrics as metrics
import sklearn.cross_validation as cv
from sklearn.externals.six import StringIO
import scipy.stats as stats
import scipy as sp
from sklearn.svm import SVC
from sklearn import cluster
from sklearn.datasets import fetch_olivetti_faces
faces = ds.fetch_olivetti_faces(data_home=None, shuffle=False, random_state=0, download_if_missing=True)
#dataset = fetch_olivetti_faces(shuffle=True)
#faces = dataset.data

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['plt', 'copy']
# `%matplotlib` prevents importing * from pylab and numpy
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-3a819f1a74fa> in <module>()
#       1 get_ipython().magic(u'pylab inline')
# ----> 2 imshow(np.array_split(faces.images[i], 8), cmap = "gray")
#
# C:\Users\Sony\Anaconda\lib\site-packages\matplotlib\pyplot.pyc in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, **kwargs)
#    2953                         vmax=vmax, origin=origin, extent=extent, shape=shape,
#    2954                         filternorm=filternorm, filterrad=filterrad,
# -> 2955                         imlim=imlim, resample=resample, url=url, **kwargs)
# ...

# %%
import copy
def blockshaped(faces, nrows, ncols):
    """
    Return an array of shape (n, nrows, ncols) where
    n * nrows * ncols = arr.size

    If arr is a 2D array, the returned array should look like n subblocks with
    each subblock preserving the "physical" layout of arr.
    """
    h, w = faces.shape
    return (faces.reshape(h//nrows, nrows, -1, ncols)
               .swapaxes(1,2)
               .reshape(-1, nrows, ncols))

# %% [markdown]
# # Разделение на блоки 8х8 для одного изображения

# %%
data = blockshaped(faces.images[0], 8, 8)
print len(blockshaped(faces.images[0], 8, 8))
# Out:
# 64

# %%
imshow(data[1], cmap = "gray")

# %%
# set up the figure
fig = plt.figure(figsize=(6, 6))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

# plot the faces:
for i in range(64):
    ax = fig.add_subplot(8, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(data[i], cmap="gray")

# %% [markdown]
# # Разделение на блоки 8х8 для массива изображений

# %%
data2 = np.zeros((400,64,8,8))
for i in range(399):
    data2[i] = blockshaped(faces.images[i], 8, 8)
print len(data2[0])
# Out:
# 64

# %%
fig = plt.figure(figsize=(6, 6))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(64):
    ax = fig.add_subplot(8, 8, i + 1, xticks=[], yticks=[])
    ax.imshow((data2[100])[i], cmap="gray")

# %% [markdown]
# # Кластеризация

# %%
from sklearn.cluster import KMeans
k_means = KMeans(n_clusters=8, random_state=0) 
k_means.fit((data2[2])[3])
y_pred = k_means.predict((data2[1])[2])

# %%
print(y_pred)
# Out:
# [3 3 3 3 3 5 5 5]

# %%
for j in xrange(4):
    for i in xrange(64):
        k_means.fit((data2[j])[i])

# %%
for j in xrange(4):
    for i in xrange(44):
        y_pred = k_means.predict((data2[j])[i])
        #print(y_pred)

# %%
from PIL import Image, ImageDraw
image = Image.open("C:/Users/Sony/Desktop/mlearn/kate.jpg")

# %%
imshow(image)

# %%
draw = ImageDraw.Draw(image) #Создаем инструмент для рисования. 
width = image.size[0] #Определяем ширину. 
height = image.size[1] #Определяем высоту. 	
pix = image.load() #Выгружаем значения пикселей.

# %%
for i in range(width):
    for j in range(height):
        a = pix[i, j][0]
        b = pix[i, j][1]
        c = pix[i, j][2]
        S = (a + b + c) // 3
        draw.point((i, j), (S, S, S))

# %%
imshow(image)

# %%
image.thumbnail((64, 64), Image.ANTIALIAS)

# %%
imshow(image)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-217-56b743bc7e30> in <module>()
# ----> 1 image.resize((image.size), 64, 64)
#
# TypeError: resize() takes at most 3 arguments (4 given)
